# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
df=pd.read_csv("TSLA.csv")
print("Number of rows and columns:", df.shape)
df.head(5)
# Out:
# Number of rows and columns: (3363, 7)
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1  2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2  2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3  2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4  2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#(740, 60, 1)

# %%
model = Sequential()#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))# Adding the output layer
model.add(Dense(units = 1))

# %%
# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 11s 33ms/step - loss: 0.0118
# Epoch 2/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.0036
# Epoch 3/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0023
# Epoch 4/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.0024
# Epoch 5/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.0021
# Epoch 6/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0022
# Epoch 7/100
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0020
# Epoch 8/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0020
# Epoch 9/100
# 24/24 [==============================] - 1s 37ms/step - loss: 0.0027
# Epoch 10/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0014
# Epoch 11/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.0017
# Epoch 12/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.0019
# Epoch 13/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0021
# Epoch 14/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0014
# Epoch 15/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0018
# Epoch 16/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0015
# Epoch 17/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.0023
# Epoch 18/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0017
# Epoch 19/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0014
# Epoch 20/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0012
# Epoch 21/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0014
# Epoch 22/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0015
# Epoch 23/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0013
# Epoch 24/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0048
# Epoch 25/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0017
# Epoch 26/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0016
# Epoch 27/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0012
# Epoch 28/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.0012
# Epoch 29/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0012
# Epoch 30/100
# 24/24 [==============================] - 1s 30ms/step - loss: 8.9858e-04
# Epoch 31/100
# 24/24 [==============================] - 1s 37ms/step - loss: 0.0014
# Epoch 32/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0013
# Epoch 33/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0011
# Epoch 34/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0012
# Epoch 35/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.0012
# Epoch 36/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0012
# Epoch 37/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.0010
# Epoch 38/100
# 24/24 [==============================] - 1s 34ms/step - loss: 9.6957e-04
# Epoch 39/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0012
# Epoch 40/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0029
# Epoch 41/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0012
# Epoch 42/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0012
# Epoch 43/100
# 24/24 [==============================] - 1s 33ms/step - loss: 9.5918e-04
# Epoch 44/100
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0011
# Epoch 45/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0012
# Epoch 46/100
# 24/24 [==============================] - 1s 37ms/step - loss: 0.0011
# Epoch 47/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0012
# Epoch 48/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.0013
# Epoch 49/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.0012
# Epoch 50/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 51/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0010
# Epoch 52/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0010
# Epoch 53/100
# 24/24 [==============================] - 1s 32ms/step - loss: 9.6274e-04
# Epoch 54/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.0010
# Epoch 55/100
# 24/24 [==============================] - 1s 33ms/step - loss: 8.0876e-04
# Epoch 56/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.0011
# Epoch 57/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0011
# Epoch 58/100
# 24/24 [==============================] - 1s 40ms/step - loss: 8.1578e-04
# Epoch 59/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.0010
# Epoch 60/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0010
# Epoch 61/100
# 24/24 [==============================] - 1s 33ms/step - loss: 9.5897e-04
# Epoch 62/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0012
# Epoch 63/100
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0012
# Epoch 64/100
# 24/24 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 65/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0032
# Epoch 66/100
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0011
# Epoch 67/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0011
# Epoch 68/100
# 24/24 [==============================] - 1s 30ms/step - loss: 8.6379e-04
# Epoch 69/100
# 24/24 [==============================] - 1s 27ms/step - loss: 9.6233e-04
# Epoch 70/100
# 24/24 [==============================] - 1s 30ms/step - loss: 9.9988e-04
# Epoch 71/100
# 24/24 [==============================] - 1s 27ms/step - loss: 9.7184e-04
# Epoch 72/100
# 24/24 [==============================] - 1s 32ms/step - loss: 7.6102e-04
# Epoch 73/100
# 24/24 [==============================] - 1s 29ms/step - loss: 8.8317e-04
# Epoch 74/100
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0011
# Epoch 75/100
# 24/24 [==============================] - 1s 31ms/step - loss: 9.9675e-04
# Epoch 76/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0010
# Epoch 77/100
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0010
# Epoch 78/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0014
# Epoch 79/100
# 24/24 [==============================] - 1s 27ms/step - loss: 8.5044e-04
# Epoch 80/100
# 24/24 [==============================] - 1s 32ms/step - loss: 7.2188e-04
# Epoch 81/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0010
# Epoch 82/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0011
# Epoch 83/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0010
# Epoch 84/100
# 24/24 [==============================] - 1s 32ms/step - loss: 9.9218e-04
# Epoch 85/100
# 24/24 [==============================] - 1s 33ms/step - loss: 8.0306e-04
# Epoch 86/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.0010
# Epoch 87/100
# 24/24 [==============================] - 1s 27ms/step - loss: 7.5901e-04
# Epoch 88/100
# 24/24 [==============================] - 1s 34ms/step - loss: 9.1461e-04
# Epoch 89/100
# 24/24 [==============================] - 1s 31ms/step - loss: 8.7378e-04
# Epoch 90/100
# 24/24 [==============================] - 1s 27ms/step - loss: 7.7325e-04
# Epoch 91/100
# 24/24 [==============================] - 1s 29ms/step - loss: 8.8033e-04
# Epoch 92/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0010
# Epoch 93/100
# 24/24 [==============================] - 1s 29ms/step - loss: 8.6447e-04
# Epoch 94/100
# 24/24 [==============================] - 1s 32ms/step - loss: 6.8317e-04
# Epoch 95/100
# 24/24 [==============================] - 1s 28ms/step - loss: 8.6320e-04
# Epoch 96/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0011
# Epoch 97/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0017
# Epoch 98/100
# 24/24 [==============================] - 1s 31ms/step - loss: 9.9189e-04
# Epoch 99/100
# 24/24 [==============================] - 1s 31ms/step - loss: 7.1484e-04
# Epoch 100/100
# 24/24 [==============================] - 1s 29ms/step - loss: 6.7654e-04

# %%
# Getting the predicted stock price of 2017
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 519):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# (459, 60, 1)

predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

predicted_stock_price
# Out:
# (459, 60, 1)
# 15/15 [==============================] - 0s 17ms/step
# array([[10.604997 ],
#        [10.689725 ],
#        [10.761495 ],
#        [10.818288 ],
#        [10.857039 ],
#        [10.865238 ],
#        [10.84997  ],
#        [10.845077 ],
#        [10.849504 ],
#        [10.857423 ],
#        [10.885301 ],
#        [10.918485 ],
#        [10.955835 ],
#        [11.0054245],
#        [11.086814 ],
#        [11.199697 ],
#        [11.298031 ],
#        [11.382467 ],
#        [11.459958 ],
#        [11.529113 ],
#        [11.591    ],
#        [11.658686 ],
#        [11.707349 ],
#        [11.698122 ],
#        [11.658952 ],
#        [11.633848 ],
#        [11.636404 ],
#        [11.631376 ],
#        [11.612826 ],
#        [11.58903  ],
#        [11.574331 ],
#        [11.601629 ],
#        [11.655195 ],
#        [11.709123 ],
#        [11.753435 ],
#        [11.782222 ],
#        [11.761463 ],
#        [11.705435 ],
#        [11.628158 ],
#        [11.576064 ],
#        [11.543054 ],
#        [11.502657 ],
#        [11.46131  ],
#        [11.39866  ],
#        [11.345998 ],
#        [11.317787 ],
#        [11.354343 ],
#        [11.354884 ],
#        [11.278972 ],
#        [11.132215 ],
#        [10.96602  ],
#        [10.824938 ],
#        [10.712221 ],
#        [10.61894  ],
#        [10.535307 ],
#        [10.453269 ],
#        [10.323372 ],
#        [10.1749735],
#        [10.022716 ],
#        [ 9.876245 ],
#        [ 9.754605 ],
#        [ 9.643898 ],
#        [ 9.54687  ],
#        [ 9.495576 ],
#        [ 9.472715 ],
#        [ 9.484041 ],
#        [ 9.56016  ],
#        [ 9.658033 ],
#        [ 9.746559 ],
#        [ 9.790004 ],
#        [ 9.800923 ],
#        [ 9.799269 ],
#        [ 9.785765 ],
#        [ 9.797817 ],
#        [ 9.836369 ],
#        [ 9.8825865],
#        [ 9.94285  ],
#        [ 9.986029 ],
#        [ 9.987131 ],
#        [ 9.969384 ],
#        [ 9.969435 ],
#        [10.01115  ],
#        [10.082608 ],
#        [10.146193 ],
#        [10.193929 ],
#        [10.217312 ],
#        [10.224759 ],
#        [10.224522 ],
#        [10.215505 ],
#        [10.206619 ],
#        [10.217112 ],
#        [10.229025 ],
#        [10.227434 ],
#        [10.195764 ],
#        [10.248052 ],
#        [10.355649 ],
#        [10.504311 ],
#        [10.658067 ],
#        [10.811624 ],
#        [10.9427395],
#        [11.043185 ],
#        [11.104975 ],
#        [11.125678 ],
#        [11.13712  ],
#        [11.160295 ],
#        [11.198014 ],
#        [11.256668 ],
#        [11.316642 ],
#        [11.361438 ],
#        [11.385398 ],
#        [11.412444 ],
#        [11.471798 ],
#        [11.579533 ],
#        [11.693152 ],
#        [11.780692 ],
#        [11.853863 ],
#        [11.934831 ],
#        [12.009796 ],
#        [12.104358 ],
#        [12.190856 ],
#        [12.250453 ],
#        [12.348398 ],
#        [12.538602 ],
#        [12.748477 ],
#        [12.887382 ],
#        [12.936141 ],
#        [12.992912 ],
#        [13.050019 ],
#        [13.095001 ],
#        [13.127919 ],
#        [13.132719 ],
#        [13.115367 ],
#        [13.086291 ],
#        [13.088508 ],
#        [13.094262 ],
#        [13.100718 ],
#        [13.113606 ],
#        [13.138704 ],
#        [13.156345 ],
#        [13.166816 ],
#        [13.160465 ],
#        [13.136859 ],
#        [13.105005 ],
#        [13.056684 ],
#        [13.008739 ],
#        [12.977129 ],
#        [12.94619  ],
#        [12.93968  ],
#        [12.971789 ],
#        [13.007784 ],
#        [12.991245 ],
#        [12.953648 ],
#        [12.9283085],
#        [12.916344 ],
#        [12.8766365],
#        [12.838184 ],
#        [12.79026  ],
#        [12.737108 ],
#        [12.693963 ],
#        [12.657327 ],
#        [12.648086 ],
#        [12.679762 ],
#        [12.714842 ],
#        [12.717398 ],
#        [12.692547 ],
#        [12.652116 ],
#        [12.622443 ],
#        [12.614122 ],
#        [12.621322 ],
#        [12.635839 ],
#        [12.666869 ],
#        [12.684726 ],
#        [12.623923 ],
#        [12.518077 ],
#        [12.4134035],
#        [12.329136 ],
#        [12.28228  ],
#        [12.267148 ],
#        [12.26673  ],
#        [12.273679 ],
#        [12.29683  ],
#        [12.322845 ],
#        [12.353378 ],
#        [12.390101 ],
#        [12.434328 ],
#        [12.477313 ],
#        [12.512534 ],
#        [12.536032 ],
#        [12.542016 ],
#        [12.528763 ],
#        [12.510289 ],
#        [12.49493  ],
#        [12.498661 ],
#        [12.510492 ],
#        [12.515513 ],
#        [12.508006 ],
#        [12.503927 ],
#        [12.504254 ],
#        [12.512823 ],
#        [12.568445 ],
#        [12.6630745],
#        [12.751525 ],
#        [12.815808 ],
#        [12.85867  ],
#        [12.907625 ],
#        [12.940433 ],
#        [12.969434 ],
#        [12.988931 ],
#        [13.0129385],
#        [13.045371 ],
#        [13.073953 ],
#        [13.07608  ],
#        [13.057988 ],
#        [13.018419 ],
#        [12.982225 ],
#        [12.949001 ],
#        [12.932196 ],
#        [12.926804 ],
#        [12.942825 ],
#        [12.957936 ],
#        [12.954893 ],
#        [12.941503 ],
#        [12.928611 ],
#        [12.930116 ],
#        [12.934816 ],
#        [12.945525 ],
#        [12.9560585],
#        [12.966876 ],
#        [12.980726 ],
#        [12.983105 ],
#        [12.994156 ],
#        [13.00202  ],
#        [13.023975 ],
#        [13.057093 ],
#        [13.092277 ],
#        [13.145635 ],
#        [13.200437 ],
#        [13.252821 ],
#        [13.298956 ],
#        [13.34213  ],
#        [13.377535 ],
#        [13.400985 ],
#        [13.419717 ],
#        [13.425993 ],
#        [13.418816 ],
#        [13.41357  ],
#        [13.409325 ],
#        [13.4149065],
#        [13.439555 ],
#        [13.465868 ],
#        [13.484935 ],
#        [13.51024  ],
#        [13.547512 ],
#        [13.606238 ],
#        [13.65344  ],
#        [13.681688 ],
#        [13.68794  ],
#        [13.694745 ],
#        [13.696662 ],
#        [13.698917 ],
#        [13.701434 ],
#        [13.69484  ],
#        [13.652829 ],
#        [13.617859 ],
#        [13.598318 ],
#        [13.58144  ],
#        [13.56345  ],
#        [13.53159  ],
#        [13.509548 ],
#        [13.500879 ],
#        [13.491964 ],
#        [13.475371 ],
#        [13.462848 ],
#        [13.446326 ],
#        [13.444445 ],
#        [13.455636 ],
#        [13.480378 ],
#        [13.503684 ],
#        [13.5224   ],
#        [13.538595 ],
#        [13.516248 ],
#        [13.468425 ],
#        [13.400238 ],
#        [13.319971 ],
#        [13.246407 ],
#        [13.215722 ],
#        [13.201848 ],
#        [13.209492 ],
#        [13.223189 ],
#        [13.236654 ],
#        [13.249158 ],
#        [13.253148 ],
#        [13.241165 ],
#        [13.244843 ],
#        [13.251313 ],
#        [13.264158 ],
#        [13.277855 ],
#        [13.282673 ],
#        [13.282869 ],
#        [13.267046 ],
#        [13.26205  ],
#        [13.258141 ],
#        [13.262257 ],
#        [13.283584 ],
#        [13.311552 ],
#        [13.334524 ],
#        [13.364681 ],
#        [13.389929 ],
#        [13.396693 ],
#        [13.388526 ],
#        [13.384799 ],
#        [13.37252  ],
#        [13.362417 ],
#        [13.358893 ],
#        [13.354258 ],
#        [13.341819 ],
#        [13.315801 ],
#        [13.271778 ],
#        [13.232005 ],
#        [13.203232 ],
#        [13.170963 ],
